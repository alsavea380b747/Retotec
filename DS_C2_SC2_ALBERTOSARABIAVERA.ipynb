# %%
import pandas as pd
import numpy as np

path= "/content/drive/MyDrive/country_vaccinations[1].csv"
vaccine=pd.read_csv(path)
print(vaccine.head(10))
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
# 5  Afghanistan      AFG  2021-02-27                 NaN                NaN
# 6  Afghanistan      AFG  2021-02-28              8200.0             8200.0
# 7  Afghanistan      AFG  2021-03-01                 NaN                NaN
# 8  Afghanistan      AFG  2021-03-02                 NaN                NaN
# 9  Afghanistan      AFG  2021-03-03                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
type(np)
# Out:
# module

# %%
vaccine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86512 entries, 0 to 86511
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              86512 non-null  object
#  1   iso_code                             86512 non-null  object
#  2   date                                 86512 non-null  object
#  3   total_vaccinations                   43607 non-null  float64
#  4   people_vaccinated                    41294 non-null  float64
#  5   people_fully_vaccinated              38802 non-null  float64
#  6   daily_vaccinations_raw               35362 non-null  float64
#  7   daily_vaccinations                   86213 non-null  float64
#  8   total_vaccinations_per_hundred       43607 non-null  float64
#  9   people_vaccinated_per_hundred        41294 non-null  float64
#  10  people_fully_vaccinated_per_hundred  38802 non-null  float64
# ...

# %%
vaccine["date"]=pd.to_datetime(vaccine["date"])
vaccine.dtypes
# Out:
# country                                        object
# iso_code                                       object
# date                                   datetime64[ns]
# total_vaccinations                            float64
# people_vaccinated                             float64
# people_fully_vaccinated                       float64
# daily_vaccinations_raw                        float64
# daily_vaccinations                            float64
# total_vaccinations_per_hundred                float64
# people_vaccinated_per_hundred                 float64
# people_fully_vaccinated_per_hundred           float64
# daily_vaccinations_per_million                float64
# vaccines                                       object
# source_name                                    object
# source_website                                 object
# dtype: object

# %%
vaccine
# Out:
#            country iso_code       date  total_vaccinations  people_vaccinated  \
# 0      Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1      Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2      Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3      Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4      Afghanistan      AFG 2021-02-26                 NaN                NaN
# ...            ...      ...        ...                 ...                ...
# 86507     Zimbabwe      ZWE 2022-03-25           8691642.0          4814582.0
# 86508     Zimbabwe      ZWE 2022-03-26           8791728.0          4886242.0
# 86509     Zimbabwe      ZWE 2022-03-27           8845039.0          4918147.0
# 86510     Zimbabwe      ZWE 2022-03-28           8934360.0          4975433.0
# 86511     Zimbabwe      ZWE 2022-03-29           9039729.0          5053114.0
#
# ...

# %%
vaccinenew = vaccine["vaccines"].str.split(',', expand=True)
vaccinenew
# Out:
#                         0                    1                 2  \
# 0         Johnson&Johnson   Oxford/AstraZeneca   Pfizer/BioNTech
# 1         Johnson&Johnson   Oxford/AstraZeneca   Pfizer/BioNTech
# 2         Johnson&Johnson   Oxford/AstraZeneca   Pfizer/BioNTech
# 3         Johnson&Johnson   Oxford/AstraZeneca   Pfizer/BioNTech
# 4         Johnson&Johnson   Oxford/AstraZeneca   Pfizer/BioNTech
# ...                   ...                  ...               ...
# 86507  Oxford/AstraZeneca    Sinopharm/Beijing           Sinovac
# 86508  Oxford/AstraZeneca    Sinopharm/Beijing           Sinovac
# 86509  Oxford/AstraZeneca    Sinopharm/Beijing           Sinovac
# 86510  Oxford/AstraZeneca    Sinopharm/Beijing           Sinovac
# 86511  Oxford/AstraZeneca    Sinopharm/Beijing           Sinovac
#
#                         3     4     5     6     7     8
# 0       Sinopharm/Beijing  None  None  None  None  None
# 1       Sinopharm/Beijing  None  None  None  None  None
# ...

# %%
vaccinenew
# Out:
#                         0                    1                 2  \
# 0         Johnson&Johnson   Oxford/AstraZeneca   Pfizer/BioNTech
# 1         Johnson&Johnson   Oxford/AstraZeneca   Pfizer/BioNTech
# 2         Johnson&Johnson   Oxford/AstraZeneca   Pfizer/BioNTech
# 3         Johnson&Johnson   Oxford/AstraZeneca   Pfizer/BioNTech
# 4         Johnson&Johnson   Oxford/AstraZeneca   Pfizer/BioNTech
# ...                   ...                  ...               ...
# 86507  Oxford/AstraZeneca    Sinopharm/Beijing           Sinovac
# 86508  Oxford/AstraZeneca    Sinopharm/Beijing           Sinovac
# 86509  Oxford/AstraZeneca    Sinopharm/Beijing           Sinovac
# 86510  Oxford/AstraZeneca    Sinopharm/Beijing           Sinovac
# 86511  Oxford/AstraZeneca    Sinopharm/Beijing           Sinovac
#
#                         3     4     5     6     7     8
# 0       Sinopharm/Beijing  None  None  None  None  None
# 1       Sinopharm/Beijing  None  None  None  None  None
# ...

# %%
vaccinenew.rename(columns = {0 : 'Vac1', 1 : 'Vac2', 2:"Vac3", 3:"Vac4"}, inplace = True)
vaccinenew
# Out:
#                      Vac1                 Vac2              Vac3  \
# 0         Johnson&Johnson   Oxford/AstraZeneca   Pfizer/BioNTech
# 1         Johnson&Johnson   Oxford/AstraZeneca   Pfizer/BioNTech
# 2         Johnson&Johnson   Oxford/AstraZeneca   Pfizer/BioNTech
# 3         Johnson&Johnson   Oxford/AstraZeneca   Pfizer/BioNTech
# 4         Johnson&Johnson   Oxford/AstraZeneca   Pfizer/BioNTech
# ...                   ...                  ...               ...
# 86507  Oxford/AstraZeneca    Sinopharm/Beijing           Sinovac
# 86508  Oxford/AstraZeneca    Sinopharm/Beijing           Sinovac
# 86509  Oxford/AstraZeneca    Sinopharm/Beijing           Sinovac
# 86510  Oxford/AstraZeneca    Sinopharm/Beijing           Sinovac
# 86511  Oxford/AstraZeneca    Sinopharm/Beijing           Sinovac
#
#                      Vac4     4     5     6     7     8
# 0       Sinopharm/Beijing  None  None  None  None  None
# 1       Sinopharm/Beijing  None  None  None  None  None
# ...

# %%
vaccine["Vac1"]=vaccinenew["Vac1"]
vaccine["Vac2"]=vaccinenew["Vac2"]
vaccine["Vac3"]=vaccinenew["Vac3"]
vaccine["Vac4"]=vaccinenew["Vac4"]
vaccine
# Out:
#            country iso_code       date  total_vaccinations  people_vaccinated  \
# 0      Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1      Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2      Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3      Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4      Afghanistan      AFG 2021-02-26                 NaN                NaN
# ...            ...      ...        ...                 ...                ...
# 86507     Zimbabwe      ZWE 2022-03-25           8691642.0          4814582.0
# 86508     Zimbabwe      ZWE 2022-03-26           8791728.0          4886242.0
# 86509     Zimbabwe      ZWE 2022-03-27           8845039.0          4918147.0
# 86510     Zimbabwe      ZWE 2022-03-28           8934360.0          4975433.0
# 86511     Zimbabwe      ZWE 2022-03-29           9039729.0          5053114.0
#
# ...

# %%
path= "/content/drive/MyDrive/country_vaccinations_by_manufacturer[1].csv"
vaccine2=pd.read_csv(path)
print(vaccine2.head(10))
# Out:
#     location        date             vaccine  total_vaccinations
# 0  Argentina  2020-12-29             Moderna                   2
# 1  Argentina  2020-12-29  Oxford/AstraZeneca                   3
# 2  Argentina  2020-12-29   Sinopharm/Beijing                   1
# 3  Argentina  2020-12-29           Sputnik V               20481
# 4  Argentina  2020-12-30             Moderna                   2
# 5  Argentina  2020-12-30  Oxford/AstraZeneca                   3
# 6  Argentina  2020-12-30   Sinopharm/Beijing                   1
# 7  Argentina  2020-12-30           Sputnik V               40583
# 8  Argentina  2020-12-31             Moderna                   2
# 9  Argentina  2020-12-31  Oxford/AstraZeneca                   3

# %%
vaccine2.dtypes
# Out:
# location              object
# date                  object
# vaccine               object
# total_vaccinations     int64
# dtype: object

# %%
vaccine2["date"]=pd.to_datetime(vaccine2["date"])

# %%
vaccine2
# Out:
#              location       date             vaccine  total_vaccinations
# 0           Argentina 2020-12-29             Moderna                   2
# 1           Argentina 2020-12-29  Oxford/AstraZeneca                   3
# 2           Argentina 2020-12-29   Sinopharm/Beijing                   1
# 3           Argentina 2020-12-29           Sputnik V               20481
# 4           Argentina 2020-12-30             Moderna                   2
# ...               ...        ...                 ...                 ...
# 35618  European Union 2022-03-29  Oxford/AstraZeneca            67403106
# 35619  European Union 2022-03-29     Pfizer/BioNTech           600519998
# 35620  European Union 2022-03-29   Sinopharm/Beijing             2301516
# 35621  European Union 2022-03-29             Sinovac                1809
# 35622  European Union 2022-03-29           Sputnik V             1845103
#
# [35623 rows x 4 columns]

# %% [markdown]
# Número de Vacunas aplicadas por cada compañia farmaceutica

# %%
vaccine2.groupby("vaccine", as_index=False).agg({"total_vaccinations":"sum"})
# Out:
#               vaccine  total_vaccinations
# 0             CanSino           271397675
# 1             Covaxin                3572
# 2     Johnson&Johnson         12611375881
# 3             Moderna        103072147621
# 4             Novavax             8268113
# 5  Oxford/AstraZeneca         46451509497
# 6     Pfizer/BioNTech        344835955037
# 7   Sinopharm/Beijing         10877006517
# 8             Sinovac         13407163275
# 9           Sputnik V          5787343199

# %% [markdown]
# Número total de Vacunas aplicadas en todo el mundo

# %%
vaccine2["total_vaccinations"].sum()
# Out:
# 537322170387

# %% [markdown]
# Promedio de vacunas aplicadas por país

# %%
vaccine2.groupby("location", as_index=False).agg({"total_vaccinations":"mean"})
# Out:
#           location  total_vaccinations
# 0        Argentina        7.104964e+06
# 1          Austria        1.864109e+06
# 2          Belgium        2.607487e+06
# 3         Bulgaria        5.712269e+05
# 4            Chile        6.652215e+06
# 5          Croatia        7.218735e+05
# 6           Cyprus        2.394061e+05
# 7          Czechia        2.471389e+06
# 8          Denmark        1.615632e+06
# 9          Ecuador        3.598674e+06
# 10         Estonia        2.971509e+05
# 11  European Union        4.682682e+07
# 12         Finland        1.438115e+06
# 13          France        1.947763e+07
# 14         Germany        1.702307e+07
# 15       Hong Kong        3.424323e+06
# 16         Hungary        1.744284e+06
# 17         Iceland        1.500218e+04
# 18         Ireland        1.419179e+06
# 19           Italy        1.727065e+07
# 20           Japan        1.737966e+07
# 21          Latvia        3.582511e+05
# 22   Liechtenstein        1.216433e+04
# ...

# %% [markdown]
# Vacunas aplicadas el día 21 de Enero en todo el mundo.

# %%
vaccine2[vaccine2["date"]=="2021-01-29"].sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# location              ArgentinaArgentinaArgentinaArgentinaAustriaAus...
# vaccine               ModernaOxford/AstraZenecaSinopharm/BeijingSput...
# total_vaccinations                                             54506092
# dtype: object

# %%
Specificdate=vaccine2[vaccine2["date"]=="2021-01-29"].groupby("location").agg({"total_vaccinations":"sum"})
print(Specificdate)
# Out:
#                 total_vaccinations
# location
# Argentina                   379788
# Austria                     264590
# Belgium                     343805
# Bulgaria                     41125
# Chile                        67448
# Croatia                      91663
# Cyprus                       22296
# Czechia                     277803
# Denmark                     248054
# Ecuador                       7091
# Estonia                      39567
# European Union            12910152
# Finland                     177281
# France                     1685948
# Germany                    2400836
# Hungary                     303019
# Ireland                     205738
# Italy                      1893925
# Latvia                       23547
# Liechtenstein                  816
# Lithuania                    94060
# Luxembourg                    8710
# Malta                        26526
# Netherlands                 351277
# Norway                      133105
# ...

# %%
Specificdate["total_vaccinations"].sum()
# Out:
# 54506092

# %%
vaccine2.columns = vaccine2.columns.str.replace("total_vaccinations", "total_vaccinations2")

# %%
vaccine2
# Out:
#              location       date             vaccine  total_vaccinations2
# 0           Argentina 2020-12-29             Moderna                    2
# 1           Argentina 2020-12-29  Oxford/AstraZeneca                    3
# 2           Argentina 2020-12-29   Sinopharm/Beijing                    1
# 3           Argentina 2020-12-29           Sputnik V                20481
# 4           Argentina 2020-12-30             Moderna                    2
# ...               ...        ...                 ...                  ...
# 35618  European Union 2022-03-29  Oxford/AstraZeneca             67403106
# 35619  European Union 2022-03-29     Pfizer/BioNTech            600519998
# 35620  European Union 2022-03-29   Sinopharm/Beijing              2301516
# 35621  European Union 2022-03-29             Sinovac                 1809
# 35622  European Union 2022-03-29           Sputnik V              1845103
#
# [35623 rows x 4 columns]

# %%
ConDiferencia=vaccine
ConDiferencia
# Out:
#            country iso_code       date  total_vaccinations  people_vaccinated  \
# 0      Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1      Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2      Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3      Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4      Afghanistan      AFG 2021-02-26                 NaN                NaN
# ...            ...      ...        ...                 ...                ...
# 86507     Zimbabwe      ZWE 2022-03-25           8691642.0          4814582.0
# 86508     Zimbabwe      ZWE 2022-03-26           8791728.0          4886242.0
# 86509     Zimbabwe      ZWE 2022-03-27           8845039.0          4918147.0
# 86510     Zimbabwe      ZWE 2022-03-28           8934360.0          4975433.0
# 86511     Zimbabwe      ZWE 2022-03-29           9039729.0          5053114.0
#
# ...

# %% [markdown]
# Nuevo DataFrame (ConDiferencias) con la nueva columna llamada "Diferencias" que es la resta entre columnas daily_vaccinations y daily_vaccionatios_raw

# %%
ConDiferencia["diferencias"]=ConDiferencia["daily_vaccinations"]-ConDiferencia["daily_vaccinations_raw"]
ConDiferencia
# Out:
#            country iso_code       date  total_vaccinations  people_vaccinated  \
# 0      Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1      Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2      Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3      Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4      Afghanistan      AFG 2021-02-26                 NaN                NaN
# ...            ...      ...        ...                 ...                ...
# 86507     Zimbabwe      ZWE 2022-03-25           8691642.0          4814582.0
# 86508     Zimbabwe      ZWE 2022-03-26           8791728.0          4886242.0
# 86509     Zimbabwe      ZWE 2022-03-27           8845039.0          4918147.0
# 86510     Zimbabwe      ZWE 2022-03-28           8934360.0          4975433.0
# 86511     Zimbabwe      ZWE 2022-03-29           9039729.0          5053114.0
#
# ...

# %% [markdown]
# Periodo de tiempo entre el registro más actual y el más antiguo (fecha)

# %%
ConDiferencia["date"].max()- ConDiferencia["date"].min()
# Out:
# Timedelta('482 days 00:00:00')

# %% [markdown]
# DataFrame nuevo con columna nueva "CanVac"

# %%
ConCantidad=vaccine
ConCantidad["CanVac"]=ConCantidad["vaccines"].str.split("/").count()
ConCantidad["CanVac"]
# Out:
# 0        86512
# 1        86512
# 2        86512
# 3        86512
# 4        86512
#          ...
# 86507    86512
# 86508    86512
# 86509    86512
# 86510    86512
# 86511    86512
# Name: CanVac, Length: 86512, dtype: int64

# %%
antes20=vaccine[vaccine["date"]<"2020-12-20"]

# %% [markdown]
# Nuevo DataFrame con datos filtrados por fecha menor a Diciembre 20 de 2020

# %%
antes20
# Out:
#              country iso_code       date  total_vaccinations  \
# 13403         Canada      CAN 2020-12-14                 5.0
# 13404         Canada      CAN 2020-12-15               727.0
# 13405         Canada      CAN 2020-12-16              3025.0
# 13406         Canada      CAN 2020-12-17              7279.0
# 13407         Canada      CAN 2020-12-18             11296.0
# ...              ...      ...        ...                 ...
# 82362  United States      USA 2020-12-15             84638.0
# 82363  United States      USA 2020-12-16            244549.0
# 82364  United States      USA 2020-12-17            517161.0
# 82365  United States      USA 2020-12-18            933551.0
# 82366  United States      USA 2020-12-19           1115437.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 13403                5.0                      NaN                     NaN
# 13404              727.0                      NaN                   722.0
# ...

# %% [markdown]
# Nuevo DataFrame con los datos filtrados por la vacuna "Pfizer/BioNTech"

# %%
pfizer=vaccine2[vaccine2["vaccine"]=="Pfizer/BioNTech"]
pfizer
# Out:
#              location       date          vaccine  total_vaccinations2
# 310         Argentina 2021-03-08  Pfizer/BioNTech                    1
# 316         Argentina 2021-03-09  Pfizer/BioNTech                    1
# 322         Argentina 2021-03-10  Pfizer/BioNTech                    1
# 328         Argentina 2021-03-11  Pfizer/BioNTech                    1
# 334         Argentina 2021-03-12  Pfizer/BioNTech                    1
# ...               ...        ...              ...                  ...
# 35583  European Union 2022-03-25  Pfizer/BioNTech            600245781
# 35592  European Union 2022-03-26  Pfizer/BioNTech            600329480
# 35601  European Union 2022-03-27  Pfizer/BioNTech            600350217
# 35610  European Union 2022-03-28  Pfizer/BioNTech            600442246
# 35619  European Union 2022-03-29  Pfizer/BioNTech            600519998
#
# [8888 rows x 4 columns]

# %%
with pd.ExcelWriter("resultadosReto.xlsx") as writer:
  ConDiferencia.to_excel(writer, sheet_name="conDiferencias")
  ConCantidad.to_excel(writer, sheet_name="conCantidad")
  antes20.to_excel(writer, sheet_name="antes20")
  pfizer.to_excel(writer, sheet_name="pfizer")
